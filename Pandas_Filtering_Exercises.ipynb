# %% [markdown]
# ## 📊 Pandas Filtreleme Egzersizleri
#
# Varsayalım elimizde aşağıdaki gibi bir DataFrame var:
#
# ```python
# import pandas as pd
#
# data = {
#     'product': ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Keyboard', 'Mouse', 'Printer'],
#     'price': [1200, 800, 300, 400, 100, 50, 500],
#     'category': ['Electronics', 'Electronics', 'Electronics', 'Electronics', 'Accessories', 'Accessories', 'Electronics'],
#     'discount': [10, 5, 20, 15, 0, 0, 25],
#     'in_stock': [True, True, False, True, True, False, True]
# }
#
# df = pd.DataFrame(data)
# ```
#
# ---
#
# ## 📌 Sorular
#
# ### 📌 Soru 1:
#
# **Fiyatı 500’den büyük ürünleri listele.**
#
# ---
#
# ### 📌 Soru 2:
#
# **Kategori 'Accessories' olan ürünleri getir.**
#
# ---
#
# ### 📌 Soru 3:
#
# **Hem fiyatı 500’den fazla hem de indirim oranı %10’dan yüksek olan ürünleri listele.**
#
# ---
#
# ### 📌 Soru 4:
#
# **Stokta olan ürünleri getir.**
#
# ---
#
# ### 📌 Soru 5:
#
# **İndirimi olmayan ürünleri listele.**
#
# ---
#
# ### 📌 Soru 6:
#
# **Fiyatı 300 ile 1000 arasında olan ürünleri listele.**
#
# ---
#
# ### 📌 Soru 7:
#
# **Kategori bilgisi 'Electronics' VE stokta olan ürünleri getir.**
#
# ---
#
# ### 📌 Soru 8:
#
# **Ürün adı 'o' harfi içeren ürünleri listele.**
# 👉 Büyük küçük harfe duyarsız olsun.
#
# ---
#
# ### 📌 Soru 9:
#
# **Fiyatı en yüksek olan ürünü getir.**
#
# ---
#
# ### 📌 Soru 10:
#
# **İndirim oranı %10, %15 veya %20 olan ürünleri listele.**
#
# ---

# %%
import pandas as pd

data = {
    'product': ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Keyboard', 'Mouse', 'Printer'],
    'price': [1200, 800, 300, 400, 100, 50, 500],
    'category': ['Electronics', 'Electronics', 'Electronics', 'Electronics', 'Accessories', 'Accessories', 'Electronics'],
    'discount': [10, 5, 20, 15, 0, 0, 25],
    'in_stock': [True, True, False, True, True, False, True]
}

df = pd.DataFrame(data)

# %%
df[df['price'] > 500]
df[df['category'] == 'Accessories']
df[(df['price']  > 500) & (df['discount'] >= 10)]
df[df['in_stock']]
df[df['discount'] == 0]
df[(df['price'] >= 300) & (df['price'] <= 1000)]
df[(df['category'] == "Electronics") & (df['in_stock'])]
df['price'].max()
df[df['discount'].isin([10, 15, 20])]
# Out:
#    product  price     category  discount  in_stock
# 0   Laptop   1200  Electronics        10      True
# 2   Tablet    300  Electronics        20     False
# 3  Monitor    400  Electronics        15      True
