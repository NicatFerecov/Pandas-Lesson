# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Vehicle Price.csv')

# %%
df.dtypes
# Out:
# name               object
# description        object
# make               object
# model              object
# year                int64
# price             float64
# engine             object
# cylinders         float64
# fuel               object
# mileage           float64
# transmission       object
# trim               object
# body               object
# doors             float64
# exterior_color     object
# interior_color     object
# drivetrain         object
# dtype: object

# %%
df['name'] = df['name'].astype('category')

# %%
df.dtypes
# Out:
# name              category
# description         object
# make                object
# model               object
# year                 int64
# price              float64
# engine              object
# cylinders          float64
# fuel                object
# mileage            float64
# transmission        object
# trim                object
# body                object
# doors              float64
# exterior_color      object
# interior_color      object
# drivetrain          object
# dtype: object

# %%
df
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 2                           2024 GMC Yukon XL Denali
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description           make  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...           Jeep
# 1     Al West is committed to offering every custome...           Jeep
# 2                                                   NaN            GMC
# 3     White Knuckle Clearcoat 2023 Dodge Durango Pur...          Dodge
# 4     \n      \n        2024 Ram 3500 Laramie Billet...            RAM
# ...                                                 ...            ...
# 997   2024 Mercedes-Benz Sprinter 2500 Cargo 144 WB ...  Mercedes-Benz
# 998   Dealer Comments +++ Price Ends 5/31/2024 +++ A...          Dodge
# 999   \n      \n        The ALL New Friendship CDJR ...           Jeep
# 1000  \n      \n        CVT with Xtronic, AWD.At Tod...         Nissan
# 1001  01u 2024 Chevrolet Silverado 2500HD Work Truck...      Chevrolet
#
#                model  year    price  \
# 0           Wagoneer  2024  74600.0
# 1     Grand Cherokee  2024  50170.0
# 2           Yukon XL  2024  96410.0
# 3            Durango  2023  46835.0
# 4               3500  2024  81663.0
# ...              ...   ...      ...
# 997    Sprinter 2500  2024  59037.0
# 998           Hornet  2024  49720.0
# 999         Wagoneer  2024  69085.0
# 1000          Murano  2024  43495.0
# 1001  Silverado 2500  2024  48995.0
#
#                                                  engine  cylinders      fuel  \
# 0                               24V GDI DOHC Twin Turbo        6.0  Gasoline
# 1                                                   OHV        6.0  Gasoline
# 2     6.2L V-8 gasoline direct injection, variable v...        8.0  Gasoline
# 3                                          16V MPFI OHV        8.0  Gasoline
# 4                              24V DDI OHV Turbo Diesel        6.0    Diesel
# ...                                                 ...        ...       ...
# 997                           16V DDI DOHC Turbo Diesel        4.0    Diesel
# 998   4 gasoline direct injection, DOHC, Multiair va...        4.0  Gasoline
# 999                             24V GDI DOHC Twin Turbo        6.0  Gasoline
# 1000  6 DOHC, variable valve control, regular unlead...        6.0  Gasoline
# 1001  8 gasoline direct injection, variable valve co...        8.0  Gasoline
#
#       mileage                         transmission                  trim  \
# 0        10.0                    8-Speed Automatic             Series II
# 1         1.0                    8-Speed Automatic                Laredo
# 2         0.0                            Automatic                Denali
# 3        32.0                    8-Speed Automatic               Pursuit
# 4        10.0                    6-Speed Automatic               Laramie
# ...       ...                                  ...                   ...
# 997      10.0                    9-Speed Automatic         Standard Roof
# 998       0.0  6-Spd Aisin F21-250 PHEV Auto Trans  Hornet R/T Plus Eawd
# 999      20.0                    8-Speed Automatic                  Base
# 1000      6.0                            Automatic    SV Intelligent AWD
# 1001     31.0                            Automatic                    WT
#
#               body  doors           exterior_color    interior_color  \
# 0              SUV    4.0                    White      Global Black
# 1              SUV    4.0                 Metallic      Global Black
# 2              SUV    4.0             Summit White  Teak/Light Shale
# 3              SUV    4.0  White Knuckle Clearcoat             Black
# 4     Pickup Truck    4.0                   Silver             Black
# ...            ...    ...                      ...               ...
# 997      Cargo Van    3.0             Arctic White             Black
# 998            SUV    4.0            Acapulco Gold             Black
# 999            SUV    4.0            Diamond Black             Black
# 1000           SUV    4.0      Pearl White Tricoat          Graphite
# 1001  Pickup Truck    4.0         Wheatland Yellow         Jet Black
#
#             drivetrain
# 0     Four-wheel Drive
# 1     Four-wheel Drive
# 2     Four-wheel Drive
# 3      All-wheel Drive
# 4     Four-wheel Drive
# ...                ...
# 997   Rear-wheel Drive
# 998    All-wheel Drive
# 999   Four-wheel Drive
# 1000   All-wheel Drive
# 1001  Rear-wheel Drive
#
# [1002 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# name                0
# description        56
# make                0
# model               0
# year                0
# price              23
# engine              2
# cylinders         105
# fuel                7
# mileage            34
# transmission        2
# trim                1
# body                3
# doors               7
# exterior_color      5
# interior_color     38
# drivetrain          0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# 5                        2024 Nissan Murano Platinum
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description           make  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...           Jeep
# 1     Al West is committed to offering every custome...           Jeep
# 3     White Knuckle Clearcoat 2023 Dodge Durango Pur...          Dodge
# 4     \n      \n        2024 Ram 3500 Laramie Billet...            RAM
# 5     \n      \n        Boasts 28 Highway MPG and 20...         Nissan
# ...                                                 ...            ...
# 997   2024 Mercedes-Benz Sprinter 2500 Cargo 144 WB ...  Mercedes-Benz
# 998   Dealer Comments +++ Price Ends 5/31/2024 +++ A...          Dodge
# 999   \n      \n        The ALL New Friendship CDJR ...           Jeep
# 1000  \n      \n        CVT with Xtronic, AWD.At Tod...         Nissan
# 1001  01u 2024 Chevrolet Silverado 2500HD Work Truck...      Chevrolet
#
#                model  year    price  \
# 0           Wagoneer  2024  74600.0
# 1     Grand Cherokee  2024  50170.0
# 3            Durango  2023  46835.0
# 4               3500  2024  81663.0
# 5             Murano  2024  46000.0
# ...              ...   ...      ...
# 997    Sprinter 2500  2024  59037.0
# 998           Hornet  2024  49720.0
# 999         Wagoneer  2024  69085.0
# 1000          Murano  2024  43495.0
# 1001  Silverado 2500  2024  48995.0
#
#                                                  engine  cylinders      fuel  \
# 0                               24V GDI DOHC Twin Turbo        6.0  Gasoline
# 1                                                   OHV        6.0  Gasoline
# 3                                          16V MPFI OHV        8.0  Gasoline
# 4                              24V DDI OHV Turbo Diesel        6.0    Diesel
# 5                                         24V MPFI DOHC        6.0  Gasoline
# ...                                                 ...        ...       ...
# 997                           16V DDI DOHC Turbo Diesel        4.0    Diesel
# 998   4 gasoline direct injection, DOHC, Multiair va...        4.0  Gasoline
# 999                             24V GDI DOHC Twin Turbo        6.0  Gasoline
# 1000  6 DOHC, variable valve control, regular unlead...        6.0  Gasoline
# 1001  8 gasoline direct injection, variable valve co...        8.0  Gasoline
#
#       mileage                         transmission                  trim  \
# 0        10.0                    8-Speed Automatic             Series II
# 1         1.0                    8-Speed Automatic                Laredo
# 3        32.0                    8-Speed Automatic               Pursuit
# 4        10.0                    6-Speed Automatic               Laramie
# 5      3838.0                        Automatic CVT              Platinum
# ...       ...                                  ...                   ...
# 997      10.0                    9-Speed Automatic         Standard Roof
# 998       0.0  6-Spd Aisin F21-250 PHEV Auto Trans  Hornet R/T Plus Eawd
# 999      20.0                    8-Speed Automatic                  Base
# 1000      6.0                            Automatic    SV Intelligent AWD
# 1001     31.0                            Automatic                    WT
#
#               body  doors           exterior_color interior_color  \
# 0              SUV    4.0                    White   Global Black
# 1              SUV    4.0                 Metallic   Global Black
# 3              SUV    4.0  White Knuckle Clearcoat          Black
# 4     Pickup Truck    4.0                   Silver          Black
# 5              SUV    4.0                    White           Gray
# ...            ...    ...                      ...            ...
# 997      Cargo Van    3.0             Arctic White          Black
# 998            SUV    4.0            Acapulco Gold          Black
# 999            SUV    4.0            Diamond Black          Black
# 1000           SUV    4.0      Pearl White Tricoat       Graphite
# 1001  Pickup Truck    4.0         Wheatland Yellow      Jet Black
#
#             drivetrain
# 0     Four-wheel Drive
# 1     Four-wheel Drive
# 3      All-wheel Drive
# 4     Four-wheel Drive
# 5      All-wheel Drive
# ...                ...
# 997   Rear-wheel Drive
# 998    All-wheel Drive
# 999   Four-wheel Drive
# 1000   All-wheel Drive
# 1001  Rear-wheel Drive
#
# [750 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# name                0
# description        56
# make                0
# model               0
# year                0
# price              23
# engine              2
# cylinders         105
# fuel                7
# mileage            34
# transmission        2
# trim                1
# body                3
# doors               7
# exterior_color      5
# interior_color     38
# drivetrain          0
# dtype: int64

# %%
df['price'].value_counts()
# Out:
# price
# 46835.0    13
# 47340.0    10
# 28860.0     6
# 54949.0     5
# 47785.0     4
#            ..
# 34492.0     1
# 36000.0     1
# 53160.0     1
# 59116.0     1
# 69697.0     1
# Name: count, Length: 859, dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# cylinders         105
# description        56
# interior_color     38
# mileage            34
# price              23
# fuel                7
# doors               7
# exterior_color      5
# body                3
# engine              2
# transmission        2
# trim                1
# name                0
# model               0
# make                0
# year                0
# drivetrain          0
# dtype: int64

# %%
round(df.isnull().sum() / len(df) * 100, 2).sort_values(ascending=False)
# Out:
# cylinders         10.48
# description        5.59
# interior_color     3.79
# mileage            3.39
# price              2.30
# fuel               0.70
# doors              0.70
# exterior_color     0.50
# body               0.30
# engine             0.20
# transmission       0.20
# trim               0.10
# name               0.00
# model              0.00
# make               0.00
# year               0.00
# drivetrain         0.00
# dtype: float64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(283)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(22, 10))
# plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
# make figure size
plt.figure(figsize=(22, 10))
# plot the null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each Column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column')

# %%
df[df['description'].isnull()].head(5)
# Out:
#                                   name description     make          model  \
# 2             2024 GMC Yukon XL Denali         NaN      GMC       Yukon XL
# 8   2024 Hyundai Tucson Hybrid Limited         NaN  Hyundai  Tucson Hybrid
# 23             2024 GMC Terrain Denali         NaN      GMC        Terrain
# 39                2024 GMC Terrain SLE         NaN      GMC        Terrain
# 58                2024 GMC Terrain SLE         NaN      GMC        Terrain
#
#     year    price                                             engine  \
# 2   2024  96410.0  6.2L V-8 gasoline direct injection, variable v...
# 8   2024  42230.0                          16V GDI DOHC Turbo Hybrid
# 23  2024  44120.0  4 gasoline direct injection, DOHC, variable va...
# 39  2024  35870.0  4 gasoline direct injection, DOHC, variable va...
# 58  2024  35870.0  4 gasoline direct injection, DOHC, variable va...
#
#     cylinders      fuel  mileage       transmission     trim body  doors  \
# 2         8.0  Gasoline      0.0          Automatic   Denali  SUV    4.0
# 8         4.0    Hybrid      5.0  6-Speed Automatic  Limited  SUV    4.0
# 23        4.0  Gasoline      0.0          Automatic   Denali  SUV    4.0
# 39        4.0  Gasoline      0.0          Automatic      SLE  SUV    4.0
# 58        4.0  Gasoline      0.0          Automatic      SLE  SUV    4.0
#
#    exterior_color        interior_color        drivetrain
# 2    Summit White      Teak/Light Shale  Four-wheel Drive
# 8     White Pearl                 Black   All-wheel Drive
# 23          Ebony               Jet Blk   All-wheel Drive
# 39   Summit White  Jet Blk Premium Clth   All-wheel Drive
# 58   Summit White  Jet Blk Premium Clth   All-wheel Drive

# %%
df['description'] = df['description'].fillna(df['description'].mode()[0])

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# cylinders         105
# interior_color     38
# mileage            34
# price              23
# fuel                7
# doors               7
# exterior_color      5
# body                3
# engine              2
# transmission        2
# trim                1
# name                0
# year                0
# description         0
# make                0
# model               0
# drivetrain          0
# dtype: int64

# %%
df[df['cylinders'].isnull()].head(5)
# Out:
#                                       name  \
# 14            2024 Chevrolet Blazer EV 2LT
# 28            2024 Chevrolet Blazer EV 2LT
# 33                         2024 Kia EV6 GT
# 35        2024 Ford Mustang Mach-E Premium
# 49  2024 Hyundai IONIQ 5 SE Standard Range
#
#                                           description       make  \
# 14  \n      \n        Sterling Gray Metallic 2024 ...  Chevrolet
# 28  Radiant Red Tintcoat 2024 Chevrolet Blazer EV ...  Chevrolet
# 33  Yacht Blue 2024 Kia EV6 GT AWD 1-Speed Automat...        Kia
# 35  2024 Ford Mustang Mach-E Premium 300A 99/86 Ci...       Ford
# 49  \n      \n        Vehicle pricing includes all...    Hyundai
#
#              model  year    price engine  cylinders      fuel  mileage  \
# 14       Blazer EV  2024  51695.0      c        NaN  Electric      4.0
# 28       Blazer EV  2024  52190.0      c        NaN  Electric      6.0
# 33             EV6  2024  49820.0      c        NaN  Electric     13.0
# 35  Mustang Mach-E  2024  47790.0      c        NaN  Electric      5.0
# 49         IONIQ 5  2024  44195.0      c        NaN  Electric     14.0
#
#          transmission               trim body  doors          exterior_color  \
# 14  1-Speed Automatic                2LT  SUV    4.0  Sterling Gray Metallic
# 28  1-Speed Automatic                2LT  SUV    4.0             Radiant Red
# 33          Automatic                 GT  SUV    4.0              Yacht Blue
# 35  1-Speed Automatic            Premium  SUV    4.0              Vapor Blue
# 49  1-Speed Automatic  SE Standard Range  SUV    4.0                   Atlas
#
#    interior_color        drivetrain
# 14          Black   All-wheel Drive
# 28          Black   All-wheel Drive
# 33          Black   All-wheel Drive
# 35          Black   All-wheel Drive
# 49           Gray  Rear-wheel Drive

# %%
df['cylinders'] = df['cylinders'].fillna(df['cylinders'].mode()[0])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# interior_color    38
# mileage           34
# price             23
# doors              7
# fuel               7
# exterior_color     5
# body               3
# transmission       2
# engine             2
# trim               1
# name               0
# cylinders          0
# year               0
# description        0
# make               0
# model              0
# drivetrain         0
# dtype: int64
